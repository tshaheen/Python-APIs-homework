# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 638

# %%
api_key = api_keys.api_key
#url = 'https://openweathermap.org/api'  + api_key 
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 
city_data = []

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    

   # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
       set_count += 1
       record_count = 0
    
    city_url = url + "&q=" + city
        
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

   # Add 1 to the record count
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

       # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
    except:
       print("City not found. Skipping...")
       pass

# Indicate that Data Loading is complete
       print("-----------------------------")
       print("Data Retrieval Complete      ")
       print("------------------")

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# OpenWeatherMap API Key
api_key = api_keys.api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | hasaki
# Processing Record 3 of Set 1 | lorengau
# Processing Record 4 of Set 1 | lompoc
# Processing Record 5 of Set 1 | longyearbyen
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | severo-kurilsk
# Processing Record 8 of Set 1 | shellbrook
# Processing Record 9 of Set 1 | esperance
# Processing Record 10 of Set 1 | manaus
# Processing Record 11 of Set 1 | butaritari
# Processing Record 12 of Set 1 | nome
# Processing Record 13 of Set 1 | mar del plata
# Processing Record 14 of Set 1 | key largo
# Processing Record 15 of Set 1 | bethel
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | tongchuan
# Processing Record 19 of Set 1 | kirakira
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | aberdeen
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | faanui
# Processing Record 24 of Set 1 | tuktoyaktuk
# Processing Record 25 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 1 | tasiilaq
# Processing Record 27 of Set 1 | kloulklubed
# Processing Record 28 of Set 1 | bad harzburg
# Processing Record 29 of Set 1 | kapaa
# Processing Record 30 of Set 1 | platanos
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | kaeo
# Processing Record 33 of Set 1 | eyl
# Processing Record 34 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 1 | santa vitoria do palmar
# Processing Record 36 of Set 1 | fortuna
# Processing Record 37 of Set 1 | thompson
# Processing Record 38 of Set 1 | castro
# Processing Record 39 of Set 1 | enumclaw
# Processing Record 40 of Set 1 | broken hill
# Processing Record 41 of Set 1 | khartoum
# Processing Record 42 of Set 1 | east london
# Processing Record 43 of Set 1 | kaitangata
# Processing Record 44 of Set 1 | luau
# Processing Record 45 of Set 1 | khatanga
# Processing Record 46 of Set 1 | new norfolk
# Processing Record 47 of Set 1 | chicama
# Processing Record 48 of Set 1 | peniche
# Processing Record 49 of Set 1 | aklavik
# Processing Record 50 of Set 1 | korce
# Processing Record 0 of Set 2 | blonduos
# City not found. Skipping...
# Processing Record 1 of Set 2 | boundiali
# Processing Record 2 of Set 2 | saucillo
# Processing Record 3 of Set 2 | junqueiropolis
# Processing Record 4 of Set 2 | sao filipe
# Processing Record 5 of Set 2 | poltavka
# Processing Record 6 of Set 2 | mandan
# Processing Record 7 of Set 2 | bilma
# Processing Record 8 of Set 2 | ampanihy
# Processing Record 9 of Set 2 | tiksi
# Processing Record 10 of Set 2 | guiren
# Processing Record 11 of Set 2 | kruisfontein
# Processing Record 12 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 2 | padang
# Processing Record 14 of Set 2 | geraldton
# Processing Record 15 of Set 2 | upernavik
# Processing Record 16 of Set 2 | saldanha
# Processing Record 17 of Set 2 | barrow
# Processing Record 18 of Set 2 | port elizabeth
# Processing Record 19 of Set 2 | camacha
# Processing Record 20 of Set 2 | geilo
# Processing Record 21 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 2 | nandu
# Processing Record 23 of Set 2 | lar gerd
# City not found. Skipping...
# Processing Record 24 of Set 2 | tura
# Processing Record 25 of Set 2 | talcahuano
# Processing Record 26 of Set 2 | sisimiut
# Processing Record 27 of Set 2 | la ronge
# Processing Record 28 of Set 2 | abu kamal
# Processing Record 29 of Set 2 | hobart
# Processing Record 30 of Set 2 | coahuayana
# Processing Record 31 of Set 2 | punta arenas
# Processing Record 32 of Set 2 | qaanaaq
# Processing Record 33 of Set 2 | vallee-jonction
# City not found. Skipping...
# Processing Record 34 of Set 2 | the valley
# Processing Record 35 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 2 | encruzilhada do sul
# Processing Record 37 of Set 2 | csany
# Processing Record 38 of Set 2 | utiroa
# City not found. Skipping...
# Processing Record 39 of Set 2 | bengkulu
# City not found. Skipping...
# Processing Record 40 of Set 2 | provideniya
# Processing Record 41 of Set 2 | jamestown
# Processing Record 42 of Set 2 | san cristobal
# Processing Record 43 of Set 2 | amuntai
# Processing Record 44 of Set 2 | arraial do cabo
# Processing Record 45 of Set 2 | sao lourenco do oeste
# City not found. Skipping...
# Processing Record 46 of Set 2 | hovd
# Processing Record 47 of Set 2 | aden
# Processing Record 48 of Set 2 | bogande
# Processing Record 49 of Set 2 | balabac
# Processing Record 0 of Set 3 | mataura
# Processing Record 1 of Set 3 | bandar
# Processing Record 2 of Set 3 | ola
# Processing Record 3 of Set 3 | churapcha
# Processing Record 4 of Set 3 | kahului
# Processing Record 5 of Set 3 | narsaq
# Processing Record 6 of Set 3 | huarmey
# Processing Record 7 of Set 3 | avarua
# Processing Record 8 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 3 | copiapo
# Processing Record 10 of Set 3 | klaksvik
# Processing Record 11 of Set 3 | lodja
# Processing Record 12 of Set 3 | flinders
# Processing Record 13 of Set 3 | urucara
# Processing Record 14 of Set 3 | saint george
# Processing Record 15 of Set 3 | san ignacio
# Processing Record 16 of Set 3 | hilo
# Processing Record 17 of Set 3 | tara
# Processing Record 18 of Set 3 | mount isa
# Processing Record 19 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 3 | guerrero negro
# Processing Record 21 of Set 3 | ranong
# Processing Record 22 of Set 3 | kiama
# Processing Record 23 of Set 3 | puerto ayora
# Processing Record 24 of Set 3 | tumen
# Processing Record 25 of Set 3 | port hedland
# Processing Record 26 of Set 3 | mozarlandia
# Processing Record 27 of Set 3 | okhotsk
# Processing Record 28 of Set 3 | port lavaca
# Processing Record 29 of Set 3 | banda aceh
# Processing Record 30 of Set 3 | georgetown
# Processing Record 31 of Set 3 | laurel
# Processing Record 32 of Set 3 | mao
# Processing Record 33 of Set 3 | salitrillo
# Processing Record 34 of Set 3 | yellowknife
# Processing Record 35 of Set 3 | boende
# Processing Record 36 of Set 3 | bonavista
# Processing Record 37 of Set 3 | acapulco
# Processing Record 38 of Set 3 | itatskiy
# Processing Record 39 of Set 3 | bolonchen
# City not found. Skipping...
# Processing Record 40 of Set 3 | touros
# Processing Record 41 of Set 3 | saskylakh
# Processing Record 42 of Set 3 | souillac
# Processing Record 43 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 44 of Set 3 | nikolskoye
# Processing Record 45 of Set 3 | busselton
# Processing Record 46 of Set 3 | atuona
# Processing Record 47 of Set 3 | portpatrick
# City not found. Skipping...
# Processing Record 48 of Set 3 | cockburn town
# Processing Record 49 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 0 of Set 4 | bredasdorp
# Processing Record 1 of Set 4 | port lincoln
# Processing Record 2 of Set 4 | saint anthony
# Processing Record 3 of Set 4 | katsuura
# Processing Record 4 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 4 | mlowo
# Processing Record 6 of Set 4 | chase
# Processing Record 7 of Set 4 | bambous virieux
# Processing Record 8 of Set 4 | port augusta
# Processing Record 9 of Set 4 | wasilla
# Processing Record 10 of Set 4 | vaini
# Processing Record 11 of Set 4 | olafsvik
# City not found. Skipping...
# Processing Record 12 of Set 4 | ribeira grande
# Processing Record 13 of Set 4 | rocha
# Processing Record 14 of Set 4 | broome
# Processing Record 15 of Set 4 | tarakan
# Processing Record 16 of Set 4 | baykit
# Processing Record 17 of Set 4 | matara
# Processing Record 18 of Set 4 | maltahohe
# Processing Record 19 of Set 4 | gigmoto
# Processing Record 20 of Set 4 | strezhevoy
# Processing Record 21 of Set 4 | marawi
# Processing Record 22 of Set 4 | sitka
# Processing Record 23 of Set 4 | luderitz
# Processing Record 24 of Set 4 | amapa
# Processing Record 25 of Set 4 | abu samrah
# Processing Record 26 of Set 4 | faya
# Processing Record 27 of Set 4 | muravlenko
# Processing Record 28 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 4 | kargasok
# Processing Record 30 of Set 4 | belyy yar
# Processing Record 31 of Set 4 | coquimbo
# Processing Record 32 of Set 4 | ovalle
# Processing Record 33 of Set 4 | charters towers
# Processing Record 34 of Set 4 | mizdah
# Processing Record 35 of Set 4 | aykhal
# Processing Record 36 of Set 4 | mount hagen
# Processing Record 37 of Set 4 | hermanus
# Processing Record 38 of Set 4 | waingapu
# Processing Record 39 of Set 4 | ponta do sol
# Processing Record 40 of Set 4 | maningrida
# Processing Record 41 of Set 4 | muslyumovo
# Processing Record 42 of Set 4 | hualmay
# Processing Record 43 of Set 4 | chokurdakh
# Processing Record 44 of Set 4 | kodinar
# Processing Record 45 of Set 4 | hirara
# Processing Record 46 of Set 4 | moerai
# Processing Record 47 of Set 4 | meulaboh
# Processing Record 48 of Set 4 | lichinga
# Processing Record 49 of Set 4 | surt
# Processing Record 0 of Set 5 | kavieng
# Processing Record 1 of Set 5 | chapais
# Processing Record 2 of Set 5 | ivankiv
# Processing Record 3 of Set 5 | bucerias
# Processing Record 4 of Set 5 | cururupu
# Processing Record 5 of Set 5 | ilulissat
# Processing Record 6 of Set 5 | mindelheim
# Processing Record 7 of Set 5 | aktau
# Processing Record 8 of Set 5 | ponta delgada
# Processing Record 9 of Set 5 | luganville
# Processing Record 10 of Set 5 | bogovarovo
# Processing Record 11 of Set 5 | kunashak
# Processing Record 12 of Set 5 | kaliua
# Processing Record 13 of Set 5 | tucupita
# Processing Record 14 of Set 5 | sobolevo
# Processing Record 15 of Set 5 | carnarvon
# Processing Record 16 of Set 5 | nanortalik
# Processing Record 17 of Set 5 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 18 of Set 5 | shenjiamen
# Processing Record 19 of Set 5 | namibe
# Processing Record 20 of Set 5 | zeya
# Processing Record 21 of Set 5 | ereymentau
# Processing Record 22 of Set 5 | winfield
# Processing Record 23 of Set 5 | sola
# Processing Record 24 of Set 5 | henties bay
# Processing Record 25 of Set 5 | dikson
# Processing Record 26 of Set 5 | braganca
# Processing Record 27 of Set 5 | labuhan
# Processing Record 28 of Set 5 | evensk
# Processing Record 29 of Set 5 | boa vista
# Processing Record 30 of Set 5 | torbay
# Processing Record 31 of Set 5 | ampere
# Processing Record 32 of Set 5 | norman wells
# Processing Record 33 of Set 5 | zyryanka
# Processing Record 34 of Set 5 | victoria
# Processing Record 35 of Set 5 | ancud
# Processing Record 36 of Set 5 | kodiak
# Processing Record 37 of Set 5 | zhanaozen
# Processing Record 38 of Set 5 | isla mujeres
# Processing Record 39 of Set 5 | guarizama
# Processing Record 40 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 5 | duluth
# Processing Record 42 of Set 5 | lebu
# Processing Record 43 of Set 5 | daru
# Processing Record 44 of Set 5 | homer
# Processing Record 45 of Set 5 | harrisonburg
# Processing Record 46 of Set 5 | tuatapere
# Processing Record 47 of Set 5 | pisco
# Processing Record 48 of Set 5 | san patricio
# Processing Record 49 of Set 5 | bintulu
# Processing Record 0 of Set 6 | weleri
# Processing Record 1 of Set 6 | imbituba
# Processing Record 2 of Set 6 | stanghelle
# Processing Record 3 of Set 6 | pacific grove
# Processing Record 4 of Set 6 | barzas
# Processing Record 5 of Set 6 | riyadh
# Processing Record 6 of Set 6 | gouyave
# Processing Record 7 of Set 6 | gorontalo
# Processing Record 8 of Set 6 | kralendijk
# Processing Record 9 of Set 6 | pevek
# Processing Record 10 of Set 6 | maghama
# City not found. Skipping...
# Processing Record 11 of Set 6 | chicla
# Processing Record 12 of Set 6 | butte
# Processing Record 13 of Set 6 | andenes
# City not found. Skipping...
# Processing Record 14 of Set 6 | vestmannaeyjar
# Processing Record 15 of Set 6 | dingle
# Processing Record 16 of Set 6 | le havre
# Processing Record 17 of Set 6 | mahebourg
# Processing Record 18 of Set 6 | kaoma
# Processing Record 19 of Set 6 | iqaluit
# Processing Record 20 of Set 6 | kaseda
# Processing Record 21 of Set 6 | fairbanks
# Processing Record 22 of Set 6 | inhambane
# Processing Record 23 of Set 6 | mehamn
# Processing Record 24 of Set 6 | guasdualito
# Processing Record 25 of Set 6 | vigrestad
# Processing Record 26 of Set 6 | leningradskiy
# Processing Record 27 of Set 6 | odessa
# Processing Record 28 of Set 6 | pandan niog
# Processing Record 29 of Set 6 | sao joao da barra
# Processing Record 30 of Set 6 | gornopravdinsk
# Processing Record 31 of Set 6 | keetmanshoop
# Processing Record 32 of Set 6 | santa rosa
# Processing Record 33 of Set 6 | san juan
# Processing Record 34 of Set 6 | cabo san lucas
# Processing Record 35 of Set 6 | buariki
# City not found. Skipping...
# Processing Record 36 of Set 6 | adzope
# Processing Record 37 of Set 6 | vao
# Processing Record 38 of Set 6 | havoysund
# Processing Record 39 of Set 6 | waipawa
# Processing Record 40 of Set 6 | palu
# Processing Record 41 of Set 6 | pekan
# Processing Record 42 of Set 6 | baruun-urt
# Processing Record 43 of Set 6 | albion
# Processing Record 44 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 45 of Set 6 | laguna
# Processing Record 46 of Set 6 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 47 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 48 of Set 6 | berbera
# City not found. Skipping...
# Processing Record 49 of Set 6 | tual
# Processing Record 0 of Set 7 | cariamanga
# Processing Record 1 of Set 7 | saint john
# Processing Record 2 of Set 7 | ubinskoye
# Processing Record 3 of Set 7 | lima
# Processing Record 4 of Set 7 | hithadhoo
# Processing Record 5 of Set 7 | flin flon
# Processing Record 6 of Set 7 | kaiwaka
# Processing Record 7 of Set 7 | vila franca do campo
# Processing Record 8 of Set 7 | lyubim
# Processing Record 9 of Set 7 | sokoni
# Processing Record 10 of Set 7 | cartagena del chaira
# Processing Record 11 of Set 7 | miranda
# Processing Record 12 of Set 7 | tecoanapa
# Processing Record 13 of Set 7 | christchurch
# Processing Record 14 of Set 7 | hoshangabad
# Processing Record 15 of Set 7 | bela vista
# Processing Record 16 of Set 7 | otane
# Processing Record 17 of Set 7 | bajil
# Processing Record 18 of Set 7 | husavik
# Processing Record 19 of Set 7 | buala
# Processing Record 20 of Set 7 | kajaani
# Processing Record 21 of Set 7 | cumanayagua
# Processing Record 22 of Set 7 | lugovoy
# Processing Record 23 of Set 7 | chengde
# Processing Record 24 of Set 7 | lata
# Processing Record 25 of Set 7 | trinidad
# Processing Record 26 of Set 7 | praya
# Processing Record 27 of Set 7 | balykshi
# City not found. Skipping...
# Processing Record 28 of Set 7 | yulara
# Processing Record 29 of Set 7 | saint-francois
# Processing Record 30 of Set 7 | codrington
# Processing Record 31 of Set 7 | babu
# Processing Record 32 of Set 7 | kokopo
# Processing Record 33 of Set 7 | shingu
# Processing Record 34 of Set 7 | los llanos de aridane
# Processing Record 35 of Set 7 | tripoli
# Processing Record 36 of Set 7 | emerald
# Processing Record 37 of Set 7 | mendoza
# Processing Record 38 of Set 7 | chuy
# Processing Record 39 of Set 7 | tsabong
# Processing Record 40 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 41 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 7 | powell
# Processing Record 43 of Set 7 | teknaf
# Processing Record 44 of Set 7 | morro bay
# Processing Record 45 of Set 7 | salaverry
# Processing Record 46 of Set 7 | port blair
# Processing Record 47 of Set 7 | marzuq
# Processing Record 48 of Set 7 | belle fourche
# Processing Record 49 of Set 7 | airai
# Processing Record 0 of Set 8 | comodoro rivadavia
# Processing Record 1 of Set 8 | mezhdurechensk
# Processing Record 2 of Set 8 | kamenka
# Processing Record 3 of Set 8 | casper
# Processing Record 4 of Set 8 | tezu
# Processing Record 5 of Set 8 | antalya
# Processing Record 6 of Set 8 | buraydah
# Processing Record 7 of Set 8 | auki
# Processing Record 8 of Set 8 | saint-philippe
# Processing Record 9 of Set 8 | gunnedah
# Processing Record 10 of Set 8 | panguna
# Processing Record 11 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 8 | ulaangom
# Processing Record 13 of Set 8 | poronaysk
# Processing Record 14 of Set 8 | ahipara
# Processing Record 15 of Set 8 | vardo
# Processing Record 16 of Set 8 | tanout
# Processing Record 17 of Set 8 | praia da vitoria
# Processing Record 18 of Set 8 | deputatskiy
# Processing Record 19 of Set 8 | dien bien
# City not found. Skipping...
# Processing Record 20 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 21 of Set 8 | challapata
# Processing Record 22 of Set 8 | dali
# Processing Record 23 of Set 8 | plouzane
# Processing Record 24 of Set 8 | guanica
# Processing Record 25 of Set 8 | melfi
# Processing Record 26 of Set 8 | zhangye
# Processing Record 27 of Set 8 | kashmor
# Processing Record 28 of Set 8 | berlevag
# Processing Record 29 of Set 8 | maarianhamina
# City not found. Skipping...
# Processing Record 30 of Set 8 | gornozavodsk
# Processing Record 31 of Set 8 | lyuban
# Processing Record 32 of Set 8 | kapoeta
# City not found. Skipping...
# Processing Record 33 of Set 8 | elizabeth city
# Processing Record 34 of Set 8 | mezen
# Processing Record 35 of Set 8 | nefteyugansk
# Processing Record 36 of Set 8 | woodbury
# Processing Record 37 of Set 8 | pafos
# City not found. Skipping...
# Processing Record 38 of Set 8 | songjianghe
# Processing Record 39 of Set 8 | bilibino
# Processing Record 40 of Set 8 | thinadhoo
# Processing Record 41 of Set 8 | santa cruz
# Processing Record 42 of Set 8 | pitimbu
# Processing Record 43 of Set 8 | te anau
# Processing Record 44 of Set 8 | parrita
# Processing Record 45 of Set 8 | khasan
# Processing Record 46 of Set 8 | atar
# Processing Record 47 of Set 8 | constitucion
# Processing Record 48 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 0 of Set 9 | waddan
# Processing Record 1 of Set 9 | naze
# Processing Record 2 of Set 9 | kasongo-lunda
# Processing Record 3 of Set 9 | sharjah
# Processing Record 4 of Set 9 | rawson
# Processing Record 5 of Set 9 | zachagansk
# City not found. Skipping...
# Processing Record 6 of Set 9 | gandevi
# Processing Record 7 of Set 9 | san
# Processing Record 8 of Set 9 | abu dhabi
# Processing Record 9 of Set 9 | barahona
# Processing Record 10 of Set 9 | richards bay
# Processing Record 11 of Set 9 | oranjestad
# Processing Record 12 of Set 9 | kitgum
# Processing Record 13 of Set 9 | agbor
# Processing Record 14 of Set 9 | port hawkesbury
# Processing Record 15 of Set 9 | forio
# Processing Record 16 of Set 9 | boyuibe
# Processing Record 17 of Set 9 | vila velha
# Processing Record 18 of Set 9 | talnakh
# Processing Record 19 of Set 9 | springbok
# Processing Record 20 of Set 9 | bafq
# Processing Record 21 of Set 9 | pathein
# Processing Record 22 of Set 9 | carthage
# Processing Record 23 of Set 9 | harper
# Processing Record 24 of Set 9 | barabinsk
# Processing Record 25 of Set 9 | clyde river
# Processing Record 26 of Set 9 | preobrazheniye
# Processing Record 27 of Set 9 | bagdarin
# Processing Record 28 of Set 9 | kamaishi
# Processing Record 29 of Set 9 | ayan
# Processing Record 30 of Set 9 | stornoway
# City not found. Skipping...
# Processing Record 31 of Set 9 | grand gaube
# Processing Record 32 of Set 9 | isangel
# Processing Record 33 of Set 9 | russell
# Processing Record 34 of Set 9 | burdur
# Processing Record 35 of Set 9 | mangrol
# Processing Record 36 of Set 9 | saint-georges
# Processing Record 37 of Set 9 | bathsheba
# Processing Record 38 of Set 9 | acarau
# City not found. Skipping...
# Processing Record 39 of Set 9 | xining
# Processing Record 40 of Set 9 | dekar
# Processing Record 41 of Set 9 | borogontsy
# Processing Record 42 of Set 9 | haines junction
# Processing Record 43 of Set 9 | port keats
# Processing Record 44 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 45 of Set 9 | belmonte
# Processing Record 46 of Set 9 | kudahuvadhoo
# Processing Record 47 of Set 9 | sterling
# Processing Record 48 of Set 9 | sciacca
# Processing Record 49 of Set 9 | avera
# Processing Record 0 of Set 10 | manta
# Processing Record 1 of Set 10 | mahon
# Processing Record 2 of Set 10 | kysyl-syr
# Processing Record 3 of Set 10 | nawalgarh
# Processing Record 4 of Set 10 | tete
# Processing Record 5 of Set 10 | mount gambier
# Processing Record 6 of Set 10 | ribas do rio pardo
# Processing Record 7 of Set 10 | uk
# City not found. Skipping...
# Processing Record 8 of Set 10 | sento se
# City not found. Skipping...
# Processing Record 9 of Set 10 | rio gallegos
# Processing Record 10 of Set 10 | araouane
# Processing Record 11 of Set 10 | puerto escondido
# Processing Record 12 of Set 10 | concordia
# Processing Record 13 of Set 10 | hamilton
# Processing Record 14 of Set 10 | gat
# Processing Record 15 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 10 | dalby
# Processing Record 17 of Set 10 | bandarbeyla
# Processing Record 18 of Set 10 | cidreira
# Processing Record 19 of Set 10 | lagoa
# Processing Record 20 of Set 10 | luqiao
# Processing Record 21 of Set 10 | vanavara
# Processing Record 22 of Set 10 | sosnovo-ozerskoye
# Processing Record 23 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 24 of Set 10 | jati
# Processing Record 25 of Set 10 | lahad datu
# Processing Record 26 of Set 10 | tiarei
# Processing Record 27 of Set 10 | makokou
# Processing Record 28 of Set 10 | kosh-agach
# Processing Record 29 of Set 10 | fort nelson
# Processing Record 30 of Set 10 | sunland park
# Processing Record 31 of Set 10 | larsnes
# Processing Record 32 of Set 10 | ouango
# Processing Record 33 of Set 10 | erenhot
# Processing Record 34 of Set 10 | alyangula
# Processing Record 35 of Set 10 | grimari
# City not found. Skipping...
# Processing Record 36 of Set 10 | korla
# City not found. Skipping...
# Processing Record 37 of Set 10 | casa grande
# Processing Record 38 of Set 10 | menongue
# Processing Record 39 of Set 10 | karlshamn
# Processing Record 40 of Set 10 | beringovskiy
# Processing Record 41 of Set 10 | kangaatsiaq
# Processing Record 42 of Set 10 | inzhavino
# Processing Record 43 of Set 10 | portland
# Processing Record 44 of Set 10 | jiaojiang
# City not found. Skipping...
# Processing Record 45 of Set 10 | srednekolymsk
# Processing Record 46 of Set 10 | tateyama
# Processing Record 47 of Set 10 | necochea
# Processing Record 48 of Set 10 | bubaque
# Processing Record 49 of Set 10 | nybro
# Processing Record 0 of Set 11 | tahara
# Processing Record 1 of Set 11 | namwala
# Processing Record 2 of Set 11 | pribelskiy
# City not found. Skipping...
# Processing Record 3 of Set 11 | yumen
# Processing Record 4 of Set 11 | planeta rica
# Processing Record 5 of Set 11 | ixtapa
# Processing Record 6 of Set 11 | barcelos
# Processing Record 7 of Set 11 | savalou
# Processing Record 8 of Set 11 | pontes e lacerda
# Processing Record 9 of Set 11 | hokitika
# Processing Record 10 of Set 11 | adrar
# Processing Record 11 of Set 11 | el alto
# Processing Record 12 of Set 11 | khandyga
# Processing Record 13 of Set 11 | grindavik
# Processing Record 14 of Set 11 | valleyview
# Processing Record 15 of Set 11 | hofn
# Processing Record 16 of Set 11 | liverpool
# Processing Record 17 of Set 11 | kachiry
# Processing Record 18 of Set 11 | bojaya
# City not found. Skipping...
# Processing Record 19 of Set 11 | creel
# Processing Record 20 of Set 11 | kishtwar
# Processing Record 21 of Set 11 | pandamatenga
# Processing Record 22 of Set 11 | matagami
# Processing Record 23 of Set 11 | shadrinsk
# Processing Record 24 of Set 11 | lokoja
# Processing Record 25 of Set 11 | la asuncion
# Processing Record 26 of Set 11 | cayenne
# Processing Record 27 of Set 11 | yinchuan
# Processing Record 28 of Set 11 | constantine
# Processing Record 29 of Set 11 | tadine
# Processing Record 30 of Set 11 | balma
# Processing Record 31 of Set 11 | artyom
# Processing Record 32 of Set 11 | morros
# Processing Record 33 of Set 11 | mayumba
# Processing Record 34 of Set 11 | manono
# Processing Record 35 of Set 11 | kutum
# Processing Record 36 of Set 11 | salalah
# Processing Record 37 of Set 11 | makarov
# Processing Record 38 of Set 11 | northam
# Processing Record 39 of Set 11 | lazaro cardenas
# Processing Record 40 of Set 11 | callaway
# Processing Record 41 of Set 11 | pangnirtung
# Processing Record 42 of Set 11 | gejiu
# Processing Record 43 of Set 11 | san andres
# Processing Record 44 of Set 11 | chernyshevskiy
# Processing Record 45 of Set 11 | najran
# Processing Record 46 of Set 11 | alice springs
# Processing Record 47 of Set 11 | ruidoso
# Processing Record 48 of Set 11 | brus laguna
# Processing Record 49 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 0 of Set 12 | zhangjiakou
# Processing Record 1 of Set 12 | westport
# Processing Record 2 of Set 12 | tsiroanomandidy
# Processing Record 3 of Set 12 | xacmaz
# Processing Record 4 of Set 12 | northview
# Processing Record 5 of Set 12 | college
# Processing Record 6 of Set 12 | peleduy
# Processing Record 7 of Set 12 | nakamura
# Processing Record 8 of Set 12 | kavaratti
# Processing Record 9 of Set 12 | santa maria
# Processing Record 10 of Set 12 | karratha
# Processing Record 11 of Set 12 | elista
# Processing Record 12 of Set 12 | mantua
# Processing Record 13 of Set 12 | ormara
# Processing Record 14 of Set 12 | benguela
# Processing Record 15 of Set 12 | yarada
# Processing Record 16 of Set 12 | thabazimbi
# Processing Record 17 of Set 12 | taganak
# Processing Record 18 of Set 12 | vila
# Processing Record 19 of Set 12 | taltal
# Processing Record 20 of Set 12 | sorland
# Processing Record 21 of Set 12 | matiguas
# Processing Record 22 of Set 12 | miri
# Processing Record 23 of Set 12 | yago
# Processing Record 24 of Set 12 | camalu
# Processing Record 25 of Set 12 | hami
# Processing Record 26 of Set 12 | talara
# Processing Record 27 of Set 12 | higueron
# Processing Record 28 of Set 12 | margate
# Processing Record 29 of Set 12 | dudinka
# Processing Record 30 of Set 12 | fukue
# Processing Record 31 of Set 12 | kalaleh
# Processing Record 32 of Set 12 | anadyr
# Processing Record 33 of Set 12 | matay
# Processing Record 34 of Set 12 | vidim
# Processing Record 35 of Set 12 | usukhchay
# Processing Record 36 of Set 12 | domat
# Processing Record 37 of Set 12 | truth or consequences
# Processing Record 38 of Set 12 | kindu
# Processing Record 39 of Set 12 | saint-augustin
# Processing Record 40 of Set 12 | diffa
# Processing Record 41 of Set 12 | kajansi
# Processing Record 42 of Set 12 | arlit
# Processing Record 43 of Set 12 | hagere selam
# Processing Record 44 of Set 12 | celestun
# Processing Record 45 of Set 12 | mezotur
# Processing Record 46 of Set 12 | mazara del vallo
# Processing Record 47 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 12 | gamba
# Processing Record 49 of Set 12 | aasiaat
# Processing Record 0 of Set 13 | borovskoy
# Processing Record 1 of Set 13 | tautira
# Processing Record 2 of Set 13 | makakilo city
# Processing Record 3 of Set 13 | bontang
# Processing Record 4 of Set 13 | price
# Processing Record 5 of Set 13 | umea
# Processing Record 6 of Set 13 | hay river
# Processing Record 7 of Set 13 | istok
# Processing Record 8 of Set 13 | penzance
# Processing Record 9 of Set 13 | luanda
# Processing Record 10 of Set 13 | emporia
# Processing Record 11 of Set 13 | valparaiso
# Processing Record 12 of Set 13 | caravelas
# Processing Record 13 of Set 13 | murray bridge
# Processing Record 14 of Set 13 | turukhansk
# Processing Record 15 of Set 13 | bossembele
# City not found. Skipping...
# Processing Record 16 of Set 13 | huambo
# Processing Record 17 of Set 13 | livingston
# Processing Record 18 of Set 13 | dickinson
# Processing Record 19 of Set 13 | palmas
# Processing Record 20 of Set 13 | zaysan
# Processing Record 21 of Set 13 | massaguet
# Processing Record 22 of Set 13 | leiyang
# Processing Record 23 of Set 13 | grafton
# Processing Record 24 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 25 of Set 13 | ocean city
# Processing Record 26 of Set 13 | konolfingen
# Processing Record 27 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 13 | nouadhibou
# Processing Record 29 of Set 13 | yangambi
# Processing Record 30 of Set 13 | coihaique
# Processing Record 31 of Set 13 | kuala krai
# City not found. Skipping...
# Processing Record 32 of Set 13 | whitehorse
# Processing Record 33 of Set 13 | dunedin
# Processing Record 34 of Set 13 | macau
# Processing Record 35 of Set 13 | kuito
# Processing Record 36 of Set 13 | kieta
# Processing Record 37 of Set 13 | alofi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame(city_data)
weather_df.head()
# weather_df.to_csv("Output/city_weather.csv", index=False, header=True)
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0   port alfred          92      ZA  1552569091        83 -33.59   26.89
# 1        hasaki           0      JP  1552568675        39  35.73  140.83
# 2      lorengau          92      PG  1552569510       100  -2.02  147.27
# 3        lompoc           1      US  1552569037        80  34.64 -120.46
# 4  longyearbyen          40      NO  1552567800        70  78.22   15.63
#
#    Max Temp  Wind Speed
# 0     73.99        3.00
# 1     44.60        8.05
# 2     82.41       16.67
# 3     51.01        5.82
# 4     -2.21        2.13

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
lats = weather_df["Lat"]
max_temps = weather_df["Max Temp"]

plt.scatter(lats, max_temps, marker="o", facecolors="red", edgecolors="black",
           alpha=0.75,)
plt.title('City Latitude vs. Max Temperature (2/26/2019)')
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperatures (F)')

plt.grid()

# %%
lats = weather_df["Lat"]
humidity = weather_df["Humidity"]

plt.scatter(lats, humidity, marker="o", facecolors="red", edgecolors="black",
           alpha=0.75,)
plt.title('City Latitude vs. Humidity (2/26/2019)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.ylim((0,105))

plt.grid()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
lats = weather_df["Lat"]
cloudiness = weather_df["Cloudiness"]

plt.scatter(lats, cloudiness, marker="o", facecolors="red", edgecolors="black",
           alpha=0.75,)
plt.title('City Latitude vs. Cloudiness (2/26/2019)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
#plt.ylim((0,105))

plt.grid()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
lats = weather_df["Lat"]
wind = weather_df["Wind Speed"]

plt.scatter(lats, wind, marker="o", facecolors="red", edgecolors="black",
           alpha=0.75,)
plt.title('City Latitude vs. Wind Speed (2/26/2019)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mpr)')
#plt.ylim((0,105))

plt.grid()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
